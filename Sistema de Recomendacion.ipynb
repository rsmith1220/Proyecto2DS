# %%
# !pip install torch-scatter -f https://data.pyg.org/whl/torch-1.13.1+cu116.html
# !pip install torch-sparse -f https://data.pyg.org/whl/torch-1.13.1+cu116.html
# !pip install torch-geometric
# !pip install umap-learn
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in links: https://data.pyg.org/whl/torch-1.13.1+cu116.html
# Collecting torch-scatter
#   Using cached torch_scatter-2.1.2.tar.gz (108 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: torch-scatter
#   Building wheel for torch-scatter (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [39 lines of output]
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11-x86_64-3.9
#       creating build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/placeholder.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/__init__.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/segment_csr.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/segment_coo.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/utils.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/scatter.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/testing.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       creating build/lib.macosx-11-x86_64-3.9/torch_scatter/composite
#       copying torch_scatter/composite/std.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter/composite
#       copying torch_scatter/composite/__init__.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter/composite
#       copying torch_scatter/composite/logsumexp.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter/composite
#       copying torch_scatter/composite/softmax.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter/composite
#       running egg_info
#       writing torch_scatter.egg-info/PKG-INFO
#       writing dependency_links to torch_scatter.egg-info/dependency_links.txt
#       writing requirements to torch_scatter.egg-info/requires.txt
#       writing top-level names to torch_scatter.egg-info/top_level.txt
#       reading manifest file 'torch_scatter.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files matching '*' found under directory 'test'
#       writing manifest file 'torch_scatter.egg-info/SOURCES.txt'
#       running build_ext
#       building 'torch_scatter._scatter_cpu' extension
#       creating build/temp.macosx-11-x86_64-3.9
#       creating build/temp.macosx-11-x86_64-3.9/csrc
#       creating build/temp.macosx-11-x86_64-3.9/csrc/cpu
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk -DWITH_PYTHON -Icsrc -I/usr/local/lib/python3.9/site-packages/torch/include -I/usr/local/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.9/site-packages/torch/include/TH -I/usr/local/lib/python3.9/site-packages/torch/include/THC -I/usr/local/include -I/usr/local/opt/openssl@1.1/include -I/usr/local/opt/sqlite/include -I/usr/local/opt/python@3.9/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c csrc/cpu/scatter_cpu.cpp -o build/temp.macosx-11-x86_64-3.9/csrc/cpu/scatter_cpu.o -O3 -Wno-sign-compare -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_clang" -DPYBIND11_STDLIB="_libcpp" -DPYBIND11_BUILD_ABI="_cxxabi1002" -DTORCH_EXTENSION_NAME=_scatter_cpu -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
#       clang: error: invalid version number in 'MACOSX_DEPLOYMENT_TARGET=11'
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for torch-scatter
#   Running setup.py clean for torch-scatter
# Failed to build torch-scatter
# ERROR: Could not build wheels for torch-scatter, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: /usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in links: https://data.pyg.org/whl/torch-1.13.1+cu116.html
# Collecting torch-sparse
#   Using cached torch_sparse-0.6.18.tar.gz (209 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from torch-sparse) (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.9/site-packages (from scipy->torch-sparse) (1.23.1)
# Building wheels for collected packages: torch-sparse
#   Building wheel for torch-sparse (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [72 lines of output]
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       running bdist_wheel
#       /usr/local/lib/python3.9/site-packages/torch/utils/cpp_extension.py:502: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#         warnings.warn(msg.format('we could not find ninja.'))
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11-x86_64-3.9
#       creating build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/matmul.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/permute.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/add.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/reduce.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/narrow.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/masked_select.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/cat.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/eye.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/convert.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/coalesce.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/__init__.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/tensor.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/bandwidth.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/mul.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/transpose.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/utils.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/diag.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/rw.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/storage.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/sample.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/spspmm.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/index_select.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/saint.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/select.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/typing.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/spadd.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/testing.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/spmm.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/metis.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       running egg_info
#       writing torch_sparse.egg-info/PKG-INFO
#       writing dependency_links to torch_sparse.egg-info/dependency_links.txt
#       writing requirements to torch_sparse.egg-info/requires.txt
#       writing top-level names to torch_sparse.egg-info/top_level.txt
#       reading manifest file 'torch_sparse.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files matching '*' found under directory 'third_party/parallel-hashmap/css'
#       warning: no previously-included files matching '*' found under directory 'third_party/parallel-hashmap/html'
#       warning: no previously-included files matching '*' found under directory 'third_party/parallel-hashmap/tests'
#       warning: no previously-included files matching '*' found under directory 'third_party/parallel-hashmap/examples'
#       warning: no previously-included files matching '*' found under directory 'third_party/parallel-hashmap/benchmark'
#       warning: no previously-included files matching '*' found under directory 'test'
#       warning: no previously-included files matching '*' found under directory 'benchmark'
#       writing manifest file 'torch_sparse.egg-info/SOURCES.txt'
#       running build_ext
#       building 'torch_sparse._relabel_cpu' extension
#       creating build/temp.macosx-11-x86_64-3.9
#       creating build/temp.macosx-11-x86_64-3.9/csrc
#       creating build/temp.macosx-11-x86_64-3.9/csrc/cpu
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk -DWITH_PYTHON -Icsrc -I/private/var/folders/04/fryprmks7_573d9qxr1s6bjh0000gn/T/pip-install-93ikm_s6/torch-sparse_8af8378ca19d45a984d0e91192dff2c6/third_party/parallel-hashmap -I/usr/local/lib/python3.9/site-packages/torch/include -I/usr/local/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.9/site-packages/torch/include/TH -I/usr/local/lib/python3.9/site-packages/torch/include/THC -I/usr/local/include -I/usr/local/opt/openssl@1.1/include -I/usr/local/opt/sqlite/include -I/usr/local/opt/python@3.9/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c csrc/cpu/relabel_cpu.cpp -o build/temp.macosx-11-x86_64-3.9/csrc/cpu/relabel_cpu.o -O3 -Wno-sign-compare -D_LIBCPP_DISABLE_AVAILABILITY -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_clang" -DPYBIND11_STDLIB="_libcpp" -DPYBIND11_BUILD_ABI="_cxxabi1002" -DTORCH_EXTENSION_NAME=_relabel_cpu -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
#       clang: error: invalid version number in 'MACOSX_DEPLOYMENT_TARGET=11'
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for torch-sparse
#   Running setup.py clean for torch-sparse
# Failed to build torch-sparse
# ERROR: Could not build wheels for torch-sparse, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: /usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: torch-geometric in /usr/local/lib/python3.9/site-packages (2.3.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from torch-geometric) (4.66.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (from torch-geometric) (1.23.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from torch-geometric) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/site-packages (from torch-geometric) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from torch-geometric) (2.28.1)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.9/site-packages (from torch-geometric) (3.0.9)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/site-packages (from torch-geometric) (1.3.0)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.9/site-packages (from torch-geometric) (5.9.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/site-packages (from jinja2->torch-geometric) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.9/site-packages (from requests->torch-geometric) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->torch-geometric) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->torch-geometric) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->torch-geometric) (2022.6.15)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/site-packages (from scikit-learn->torch-geometric) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn->torch-geometric) (3.2.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: /usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: umap-learn in /usr/local/lib/python3.9/site-packages (0.5.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/site-packages (from umap-learn) (1.23.1)
# Requirement already satisfied: scipy>=1.3.1 in /usr/local/lib/python3.9/site-packages (from umap-learn) (1.11.1)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.9/site-packages (from umap-learn) (1.3.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.9/site-packages (from umap-learn) (0.58.0)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.9/site-packages (from umap-learn) (0.5.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: tbb>=2019.0 in /usr/local/lib/python3.9/site-packages (from umap-learn) (2021.10.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.9/site-packages (from numba>=0.51.2->umap-learn) (0.41.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.9/site-packages (from pynndescent>=0.5->umap-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/site-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: /usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip

# %%
# !pip3 install torch==1.8.1+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip3 install torch-scatter
# !pip3 install torch-sparse
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.8.1+cu111 (from versions: 1.7.1, 1.8.0, 1.8.1, 1.9.0, 1.9.1, 1.10.0, 1.10.1, 1.10.2, 1.11.0, 1.12.0, 1.12.1, 1.13.0, 1.13.1, 2.0.0, 2.0.1, 2.1.0)
# ERROR: No matching distribution found for torch==1.8.1+cu111
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: /usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting torch-scatter
#   Using cached torch_scatter-2.1.2.tar.gz (108 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: torch-scatter
#   Building wheel for torch-scatter (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [39 lines of output]
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11-x86_64-3.9
#       creating build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/placeholder.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/__init__.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/segment_csr.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/segment_coo.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/utils.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/scatter.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       copying torch_scatter/testing.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter
#       creating build/lib.macosx-11-x86_64-3.9/torch_scatter/composite
#       copying torch_scatter/composite/std.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter/composite
#       copying torch_scatter/composite/__init__.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter/composite
#       copying torch_scatter/composite/logsumexp.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter/composite
#       copying torch_scatter/composite/softmax.py -> build/lib.macosx-11-x86_64-3.9/torch_scatter/composite
#       running egg_info
#       writing torch_scatter.egg-info/PKG-INFO
#       writing dependency_links to torch_scatter.egg-info/dependency_links.txt
#       writing requirements to torch_scatter.egg-info/requires.txt
#       writing top-level names to torch_scatter.egg-info/top_level.txt
#       reading manifest file 'torch_scatter.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files matching '*' found under directory 'test'
#       writing manifest file 'torch_scatter.egg-info/SOURCES.txt'
#       running build_ext
#       building 'torch_scatter._scatter_cpu' extension
#       creating build/temp.macosx-11-x86_64-3.9
#       creating build/temp.macosx-11-x86_64-3.9/csrc
#       creating build/temp.macosx-11-x86_64-3.9/csrc/cpu
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk -DWITH_PYTHON -Icsrc -I/usr/local/lib/python3.9/site-packages/torch/include -I/usr/local/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.9/site-packages/torch/include/TH -I/usr/local/lib/python3.9/site-packages/torch/include/THC -I/usr/local/include -I/usr/local/opt/openssl@1.1/include -I/usr/local/opt/sqlite/include -I/usr/local/opt/python@3.9/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c csrc/cpu/scatter_cpu.cpp -o build/temp.macosx-11-x86_64-3.9/csrc/cpu/scatter_cpu.o -O3 -Wno-sign-compare -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_clang" -DPYBIND11_STDLIB="_libcpp" -DPYBIND11_BUILD_ABI="_cxxabi1002" -DTORCH_EXTENSION_NAME=_scatter_cpu -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
#       clang: error: invalid version number in 'MACOSX_DEPLOYMENT_TARGET=11'
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for torch-scatter
#   Running setup.py clean for torch-scatter
# Failed to build torch-scatter
# ERROR: Could not build wheels for torch-scatter, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: /usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting torch-sparse
#   Using cached torch_sparse-0.6.18.tar.gz (209 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/site-packages (from torch-sparse) (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /usr/local/lib/python3.9/site-packages (from scipy->torch-sparse) (1.23.1)
# Building wheels for collected packages: torch-sparse
#   Building wheel for torch-sparse (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [72 lines of output]
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       Compiling without OpenMP...
#       running bdist_wheel
#       /usr/local/lib/python3.9/site-packages/torch/utils/cpp_extension.py:502: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#         warnings.warn(msg.format('we could not find ninja.'))
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-11-x86_64-3.9
#       creating build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/matmul.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/permute.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/add.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/reduce.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/narrow.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/masked_select.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/cat.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/eye.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/convert.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/coalesce.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/__init__.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/tensor.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/bandwidth.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/mul.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/transpose.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/utils.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/diag.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/rw.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/storage.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/sample.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/spspmm.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/index_select.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/saint.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/select.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/typing.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/spadd.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/testing.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/spmm.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       copying torch_sparse/metis.py -> build/lib.macosx-11-x86_64-3.9/torch_sparse
#       running egg_info
#       writing torch_sparse.egg-info/PKG-INFO
#       writing dependency_links to torch_sparse.egg-info/dependency_links.txt
#       writing requirements to torch_sparse.egg-info/requires.txt
#       writing top-level names to torch_sparse.egg-info/top_level.txt
#       reading manifest file 'torch_sparse.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no previously-included files matching '*' found under directory 'third_party/parallel-hashmap/css'
#       warning: no previously-included files matching '*' found under directory 'third_party/parallel-hashmap/html'
#       warning: no previously-included files matching '*' found under directory 'third_party/parallel-hashmap/tests'
#       warning: no previously-included files matching '*' found under directory 'third_party/parallel-hashmap/examples'
#       warning: no previously-included files matching '*' found under directory 'third_party/parallel-hashmap/benchmark'
#       warning: no previously-included files matching '*' found under directory 'test'
#       warning: no previously-included files matching '*' found under directory 'benchmark'
#       writing manifest file 'torch_sparse.egg-info/SOURCES.txt'
#       running build_ext
#       building 'torch_sparse._relabel_cpu' extension
#       creating build/temp.macosx-11-x86_64-3.9
#       creating build/temp.macosx-11-x86_64-3.9/csrc
#       creating build/temp.macosx-11-x86_64-3.9/csrc/cpu
#       clang -Wno-unused-result -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX.sdk -DWITH_PYTHON -Icsrc -I/private/var/folders/04/fryprmks7_573d9qxr1s6bjh0000gn/T/pip-install-ryxf98mm/torch-sparse_e1bc7b9f85dc4700a9fcf135d954ea8f/third_party/parallel-hashmap -I/usr/local/lib/python3.9/site-packages/torch/include -I/usr/local/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.9/site-packages/torch/include/TH -I/usr/local/lib/python3.9/site-packages/torch/include/THC -I/usr/local/include -I/usr/local/opt/openssl@1.1/include -I/usr/local/opt/sqlite/include -I/usr/local/opt/python@3.9/Frameworks/Python.framework/Versions/3.9/include/python3.9 -c csrc/cpu/relabel_cpu.cpp -o build/temp.macosx-11-x86_64-3.9/csrc/cpu/relabel_cpu.o -O3 -Wno-sign-compare -D_LIBCPP_DISABLE_AVAILABILITY -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE="_clang" -DPYBIND11_STDLIB="_libcpp" -DPYBIND11_BUILD_ABI="_cxxabi1002" -DTORCH_EXTENSION_NAME=_relabel_cpu -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
#       clang: error: invalid version number in 'MACOSX_DEPLOYMENT_TARGET=11'
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for torch-sparse
#   Running setup.py clean for torch-sparse
# Failed to build torch-sparse
# ERROR: Could not build wheels for torch-sparse, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: /usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip

# %%
# importamos varias librerias
import json
# Importamos la Path class del modulo pathlib y lo renombramos como Data_Path
from pathlib import Path as Data_Path
# importamos el modulo os y funciones especificas
import os 
from os.path import isfile, join
#immportamos los modulos pickle (para trabajar con la serializacion de objetos de python) y random
import pickle
import random

import numpy as np
# importamos la libreria networkx y la renombramos nx
import networkx as nx
import pandas as pd
# importamos las funciones de las metricas de sklearn
from sklearn.metrics import f1_score, roc_auc_score
import matplotlib.pyplot as plt
# hacemos los graficos inline
# %matplotlib inline
# importamos la funcion tqdm del modulo 
from tqdm.notebook import tqdm

# %%
# Importamos librerías necesarias para Machine Learning
from typing import Optional, Union  # el módulo typing sirve para manejar tipos opcionales y uniones

import torch  
from torch import Tensor  # importamos la clase Tensor 
import torch.nn as nn  # importamos el módulo de redes neuronales de PyTorch
from torch.nn import Embedding, ModuleList, Linear  # Importamos clases específicas para capas de Embedding, ModuleList y Linear
import torch.nn.functional as F  # Importamos funciones de activación y operaciones de PyTorch

import torch_geometric  # Importamos PyTorch Geometric para el aprendizaje en grafos
import torch_geometric.nn as pyg_nn  # Importamos el módulo de redes neuronales específico de PyTorch Geometric
from torch_geometric.data import Data  # Importamos la clase Data para gestionar datos en grafos
from torch_geometric.transforms import RandomLinkSplit  # Importamos una transformación para dividir enlaces de forma aleatoria
from torch.nn.modules.loss import _Loss  # Importamos la clase _Loss para definir funciones de pérdida personalizadas

from torch_geometric.nn.conv import LGConv, GATConv, SAGEConv  # Importamos capas de convolución específicas para grafos
from torch_geometric.typing import Adj, OptTensor, SparseTensor  # Importamos tipos de datos específicos para grafos

print(f"Versión de Torch: {torch.__version__}; Versión de Torch-cuda: {torch.version.cuda}; Versión de Torch Geometric: {torch_geometric.__version()}.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 19>()
#      16 from torch_geometric.nn.conv import LGConv, GATConv, SAGEConv  # Importamos capas de convolución específicas para grafos
#      17 from torch_geometric.typing import Adj, OptTensor, SparseTensor  # Importamos tipos de datos específicos para grafos
# ---> 19 print(f"Versión de Torch: {torch.__version__}; Versión de Torch-cuda: {torch.version.cuda}; Versión de Torch Geometric: {torch_geometric.__version()}.")
#
# AttributeError: module 'torch_geometric' has no attribute '__version'

# %%
# Establecemos la semilla para garantizar la reproducibilidad
seed = 224  # seteamos la semilla
torch.manual_seed(seed)  # Establecemos la semilla para PyTorch para reproducibilidad
np.random.seed(seed)  # Establecemos la semilla para NumPy para reproducibilidad
random.seed(seed)  # Establecemos la semilla para el generador de números aleatorios de Python para reproducibilidad

# %%
import pandas as pd
playlist_df = pd.read_csv('playlists.csv')
playlist_df.head()  # muestra las primeras filas del DataFrame
# Out:
#    pid              name description  num_tracks  num_albums  num_followers  \
# 0    0        Throwbacks         NaN          52          47              1
# 1    1  Awesome Playlist         NaN          39          23              1
# 2    2           korean          NaN          64          51              1
# 3    3               mat         NaN         126         107              1
# 4    4               90s         NaN          17          16              2
#
#    collaborative  modified_at  num_edits  duration_ms  num_artists
# 0          False   1493424000          6     11532414           37
# 1          False   1506556800          5     11656470           21
# 2          False   1505692800         18     14039958           31
# 3          False   1501027200          4     28926058           86
# 4          False   1401667200          7      4335282           16

# %%
print(playlist_df.iloc[0])
# Out:
# pid                       0
# name             Throwbacks
# description             NaN
# num_tracks               52
# num_albums               47
# num_followers             1
# collaborative         False
# modified_at      1493424000
# num_edits                 6
# duration_ms        11532414
# num_artists              37
# Name: 0, dtype: object

# %%
"""Creamos la clase Track que tiene los atributos:
1. URI el cual es un id 
2. Nombre
3. ID y nombre del artista
4. parent playlist"""

class Track:
    # constructor
    def __init__(self, track_dict, playlist):
        self.uri = track_dict["track_uri"]
        self.name = track_dict["track_name"]
        self.artist_uri = track_dict["artist_uri"]
        self.artist_name = track_dict["artist_name"]
        self.playlist = playlist
  
    # to string
    def __str__(self):
        return f"Track {self.uri} called {self.name} by {self.artist_uri} ({self.artist_name}) in playlist {self.playlist}."
    # metodo que retorna el codigo de la pista
    def __repr__(self):
        return f"Track {self.uri}"

# %%
"""Creamos la clase playlist que tiene los atributos:
1.  Name (playlist y si index asociado)
2. Title (titulo en el dataset)
3. Loaded dictionary from the raw json for the playlist
4. Dictionary of tracks (track_uri : Track), populated by .load_tracks()
5. List of artists uris"""
